# %% [markdown]
# ### Data gathering

# %%
import pandas as pd

df = pd.read_csv("results.csv").copy()
df.head(5)
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df.shape
# Out:
# (45315, 9)

# %% [markdown]
# ### Data Assessment

# %% [markdown]
# let's proceed to assess the quality and tidiness of our data

# %% [markdown]
# - checking for erronous data type

# %%
df.dtypes

# %% [markdown]
# - The date column has as data type object....we could consider changing it to date data type to permit easier extraction of month, year or day attributes during further analysis

# %%
df.describe()
# Out:
#          home_score    away_score
# count  45315.000000  45315.000000
# mean       1.739314      1.178241
# std        1.746904      1.392095
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %% [markdown]
# Here we observe a maximum of 31 and 21 goals...further research can be carried out to verify authenticity of this data

# %%
df.query('home_score==31')
# Out:
#              date  home_team       away_team  home_score  away_score  \
# 24160  2001-04-11  Australia  American Samoa          31           0
#
#                          tournament           city    country  neutral
# 24160  FIFA World Cup qualification  Coffs Harbour  Australia    False

# %%
df.query('away_score==21')
# Out:
#              date home_team    away_team  home_score  away_score  \
# 27753  2005-03-11      Guam  North Korea           0          21
#
#               tournament    city country  neutral
# 27753  EAFF Championship  Taipei  Taiwan     True

# %% [markdown]
# - Upon verification to find if these number of goals were accurate, we found these statistics to be correct.

# %%
df.isnull().count()
# Out:
# date          45315
# home_team     45315
# away_team     45315
# home_score    45315
# away_score    45315
# tournament    45315
# city          45315
# country       45315
# neutral       45315
# dtype: int64

# %% [markdown]
# - No null values, let's proceed to check for duplicates

# %%
sum(df.duplicated())
# Out:
# 0

# %% [markdown]
# - No duplicate rows hence no issue to clean with respect to that

# %%
df.sample(45)
# Out:
#              date             home_team             away_team  home_score  \
# 30217  2007-12-12              Tanzania               Somalia           1
# 33558  2011-07-03                  Laos              Cambodia           6
# 6608   1967-08-02                Guyana              Suriname           0
# 4270   1957-10-02               Denmark   Republic of Ireland           0
# 45178  2023-11-16               Estonia               Austria           0
# 23029  2000-03-19              Dominica                 Haiti           1
# 11240  1979-09-04                  Fiji       Solomon Islands           2
# 21247  1997-10-11                Sweden               Estonia           1
# 2640   1946-10-08              Bulgaria               Romania           2
# 5196   1962-09-05           Netherlands               Curaçao           8
# 11210  1979-08-22              Colombia             Venezuela           4
# 21975  1998-10-14        Czech Republic               Estonia           4
# 10517  1977-10-02             Hong Kong                Kuwait           1
# 19618  1995-11-29              Zanzibar                Rwanda           2
# 5194   1962-09-02               Iceland   Republic of Ireland           1
# 1836   1935-10-13               Germany                Latvia           3
# 4419   1958-09-02              Malaysia             Singapore           0
# 4570   1959-09-02              Malaysia      Vietnam Republic           4
# 18182  1993-07-02                 Syria                Taiwan           8
# 19179           0  African Cup of Nations qualification          Luanda
# 45096           1          FIFA World Cup qualification         Colombo
# 32965           0       CFU Caribbean Cup qualification    San Fernando
# 19910           0                              Friendly       Rose Hill
# 4341            1                     Copa Oswaldo Cruz  Rio de Janeiro
# 22439           1                              Friendly        Asunción
# 5353            1                          Copa América          La Paz
# 36858           0  African Cup of Nations qualification           Praia
# 8283            0                         AFC Asian Cup         Bangkok
# 38985           0                              Friendly         Nairobi
# 1423            0                              Friendly        Helsinki
# 5982            1  African Cup of Nations qualification        Khartoum
# 36251           1                              Friendly           Sofia
# 2805            1                     CCCF Championship       Guatemala
# 41012           0               UEFA Euro qualification           Udine
# 21796           1  African Cup of Nations qualification         Nairobi
#
#                     country  neutral
# 30217              Tanzania    False
# 33558                  Laos    False
# 6608                 Guyana    False
# 4270                Denmark    False
# 45178               Estonia    False
# 23029              Dominica    False
# 11240                  Fiji    False
# 21247                Sweden    False
# 2640                Albania     True
# 5196            Netherlands    False
# 11210              Colombia    False
# 21975        Czech Republic    False
# 10517             Hong Kong    False
# 19618                Uganda     True
# 5194                Iceland    False
# 1836                Germany    False
# 4419                 Malaya     True
# 4570                 Malaya    False
# 18182                 Syria    False
# 40566                  Laos    False
# 27902        Czech Republic    False
# 40494           Switzerland    False
# 26546  United Arab Emirates    False
# 18110         United States    False
# 8040           Soviet Union    False
# 41590                Latvia    False
# 36330               Burundi    False
# 22371                Israel    False
# 22335   Trinidad and Tobago     True
# 19179                Angola    False
# 45096             Sri Lanka    False
# 32965   Trinidad and Tobago    False
# 19910             Mauritius    False
# 4341                 Brazil    False
# 22439              Paraguay    False
# 5353                Bolivia     True
# 36858            Cape Verde    False
# 8283               Thailand     True
# 38985                 Kenya    False
# 1423                Finland    False
# 5982                  Sudan    False
# 36251              Bulgaria    False
# 2805              Guatemala     True
# 41012                 Italy    False
# 21796                 Kenya    False

# %% [markdown]
# ### Data Cleaning
#
# #### Define
#
# 1 - Converting the date field to a proper data type

# %% [markdown]
# #### Code

# %%
df['date']=pd.to_datetime(df.date)

# %% [markdown]
# #### Test

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45315 entries, 0 to 45314
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        45315 non-null  datetime64[ns]
#  1   home_team   45315 non-null  object
#  2   away_team   45315 non-null  object
#  3   home_score  45315 non-null  int64
#  4   away_score  45315 non-null  int64
#  5   tournament  45315 non-null  object
#  6   city        45315 non-null  object
#  7   country     45315 non-null  object
#  8   neutral     45315 non-null  bool
# dtypes: bool(1), datetime64[ns](1), int64(2), object(5)
# memory usage: 2.8+ MB

# %% [markdown]
# it can be observed that our date field data type has been changed....hence our cleaning was successful

# %% [markdown]
# ### Data Visualisation
